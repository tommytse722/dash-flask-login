# %%
import LSTM_mgt as lm
# Out:
# Using TensorFlow backend.

# %%
lm.prediction()
# Out:
# Epoch 1/100
# 335/335 [==============================] - 7s 21ms/step - loss: 0.1089
# Epoch 2/100
# 335/335 [==============================] - 6s 16ms/step - loss: 0.0239
# Epoch 3/100
# 335/335 [==============================] - 5s 16ms/step - loss: 0.0209
# Epoch 4/100
# 335/335 [==============================] - 4s 11ms/step - loss: 0.0174
# Epoch 5/100
# 335/335 [==============================] - 6s 18ms/step - loss: 0.0158
# Epoch 6/100
# 335/335 [==============================] - 5s 16ms/step - loss: 0.0143
# Epoch 7/100
# 335/335 [==============================] - 4s 12ms/step - loss: 0.0157
# Epoch 8/100
# 335/335 [==============================] - 4s 13ms/step - loss: 0.0172
# Epoch 9/100
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0147
# Epoch 10/100
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0137
# Epoch 11/100
# 335/335 [==============================] - 4s 11ms/step - loss: 0.0140
# Epoch 12/100
# ...
