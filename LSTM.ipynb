# %%
import LSTM_mgt as lm
# Out:
# Using TensorFlow backend.

# %%
lm.prediction()
# Out:
# Epoch 1/5
# 336/336 [==============================] - 3s 10ms/step - loss: 0.0876
# Epoch 2/5
# 336/336 [==============================] - 2s 6ms/step - loss: 0.0240A: 1s -
# Epoch 3/5
# 336/336 [==============================] - 2s 6ms/step - loss: 0.0168
# Epoch 4/5
# 336/336 [==============================] - 2s 6ms/step - loss: 0.0158A: 0s - lo
# Epoch 5/5
# 336/336 [==============================] - 2s 6ms/step - loss: 0.0170
# rmse:52.351173641215475
# Epoch 1/5
# 336/336 [==============================] - 3s 10ms/step - loss: 0.0902
# Epoch 2/5
# 336/336 [==============================] - 2s 6ms/step - loss: 0.0196
# Epoch 3/5
# 336/336 [==============================] - 2s 6ms/step - loss: 0.0146
# Epoch 4/5
# 336/336 [==============================] - 2s 6ms/step - loss: 0.0158
# Epoch 5/5
# 336/336 [==============================] - 2s 6ms/step - loss: 0.0125
# rmse:76.85534737996265
# Epoch 1/5
# 336/336 [==============================] - 4s 11ms/step - loss: 0.1010
# ...
