# %%
import LSTM_mgt as lm
# Out:
# Using TensorFlow backend.

# %%
lm.drop_forecast_table()

# %%
lm.create_forecast_table()

# %%
lm.prediction()
# Out:
# Epoch 1/100
# 335/335 [==============================] - 7s 20ms/step - loss: 0.0201
# Epoch 2/100
# 335/335 [==============================] - 6s 17ms/step - loss: 0.0057
# Epoch 3/100
# 335/335 [==============================] - 5s 16ms/step - loss: 0.0051
# Epoch 4/100
# 335/335 [==============================] - 4s 12ms/step - loss: 0.0048
# Epoch 5/100
# 335/335 [==============================] - 5s 16ms/step - loss: 0.0046
# Epoch 6/100
# 335/335 [==============================] - 6s 19ms/step - loss: 0.0052
# Epoch 7/100
# 335/335 [==============================] - 4s 12ms/step - loss: 0.0043
# Epoch 8/100
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0035
# Epoch 9/100
# 335/335 [==============================] - 5s 15ms/step - loss: 0.0037
# Epoch 10/100
# 335/335 [==============================] - 5s 14ms/step - loss: 0.0035
# Epoch 11/100
# 335/335 [==============================] - 4s 11ms/step - loss: 0.0035
# Epoch 12/100
# ...
